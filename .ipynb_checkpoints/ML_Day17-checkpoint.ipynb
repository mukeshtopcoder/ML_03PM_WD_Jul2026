# %%
dataset = {
    'Movies':[
        'Avenger',
        'Spiderman',
        'Intersteller'
    ],
    'Genres':[
        'Action,Sci-Fi,International,Hollywood',
        'Action,Sci-Fi,International,Romantic',
        'Action,Sci-Fi,Drama'
    ],
    'Movie_Poster_Link':[
        'https://wallpapers.com/images/hd/marvel-avengers-team-battle-scene-7ghqv7ih0domruuq.jpg',
        'https://th.bing.com/th/id/OIP.-uU8hz-3YBvgugH9gCJupQHaEK?r=0&o=7rm=3&rs=1&pid=ImgDetMain&o=7&rm=3',
        'https://wallpapercave.com/wp/wp1818008.jpg'
    ]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#          Movies                                 Genres  \
# 0       Avenger  Action,Sci-Fi,International,Hollywood
# 1     Spiderman   Action,Sci-Fi,International,Romantic
# 2  Intersteller                    Action,Sci-Fi,Drama
#
#                                    Movie_Poster_Link
# 0  https://wallpapers.com/images/hd/marvel-avenge...
# 1  https://th.bing.com/th/id/OIP.-uU8hz-3YBvgugH9...
# 2         https://wallpapercave.com/wp/wp1818008.jpg

# %%
# !pip install Pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,3))
response = requests.get(df['Movie_Poster_Link'][0])
img = Image.open(BytesIO(response.content))
plt.imshow(img)
plt.show()

# %%
df['Movie_Poster_Link'][0]
# Out:
# 'https://wallpapers.com/images/hd/marvel-avengers-team-battle-scene-7ghqv7ih0domruuq.jpg'
